# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber']
# Out:
# 0    10045.0
# 1        NaN
# 2    10065.0
# 3        NaN
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %%
np_arange = np.arange(1, df.From_To.count()+1)
np_arange
# Out:
# array([1, 2, 3, 4, 5])

# %%
#Now set this indes in dataframe to add data using for loop
df.set_index(np_arange , inplace =True)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN           NaN            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis           NaN          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
 for i in np.arange(1, df.From_To.count()+1):
        if pd.isnull(df.loc[i,'FlightNumber']):
            df.loc[i,'FlightNumber'] = df.FlightNumber.loc[i-1,] + 10;
df['FlightNumber']
df['FlightNumber'].astype(int)
# Out:
# 1    10045
# 2    10055
# 3    10065
# 4    10075
# 5    10085
# Name: FlightNumber, dtype: int32

# %%
TemporaryDf = df.copy()

# %%
TemporaryDf[['From', 'To'] ]= TemporaryDf.From_To.str.split("_" , expand= True)
TemporaryDf
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 1    LoNDon      paris
# 2    MAdrid      miLAN
# 3    londON  StockhOlm
# 4  Budapest      PaRis
# 5  Brussels     londOn

# %%
temporayFrom =  TemporaryDf['From'].str.capitalize()
temporayFrom
# Out:
# 1      London
# 2      Madrid
# 3      London
# 4    Budapest
# 5    Brussels
# Name: From, dtype: object

# %%
TemporaryTo = TemporaryDf['To'].str.capitalize()
TemporaryTo
# Out:
# 1        Paris
# 2        Milan
# 3    Stockholm
# 4        Paris
# 5       London
# Name: To, dtype: object

# %%
temporaryDf = TemporaryDf['From_To'].str.capitalize()

temporaryDf
# Out:
# 1        London_paris
# 2        Madrid_milan
# 3    London_stockholm
# 4      Budapest_paris
# 5     Brussels_london
# Name: From_To, dtype: object

# %%
TemporaryDf
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 1    LoNDon      paris
# 2    MAdrid      miLAN
# 3    londON  StockhOlm
# 4  Budapest      PaRis
# 5  Brussels     londOn

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df.drop("From_To", axis= 1 , inplace =True)
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 1       10045.0      [23, 47]               KLM(!)
# 2       10055.0            []    <Air France> (12)
# 3       10065.0  [24, 43, 87]  (British Airways. )
# 4       10075.0          [13]       12. Air France
# 5       10085.0      [67, 32]          "Swiss Air"

# %%
df['From_To'] = TemporaryDf['From_To']
df['From_To']  = df['From_To'].str.capitalize()
df
# Out:
#    FlightNumber  RecentDelays              Airline           From_To
# 1       10045.0      [23, 47]               KLM(!)      London_paris
# 2       10055.0            []    <Air France> (12)      Madrid_milan
# 3       10065.0  [24, 43, 87]  (British Airways. )  London_stockholm
# 4       10075.0          [13]       12. Air France    Budapest_paris
# 5       10085.0      [67, 32]          "Swiss Air"   Brussels_london

# %%
df['RecentDelays'].dtypes
df.dtypes
# Out:
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# From_To          object
# dtype: object

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline           From_To
# 1       10045.0      [23, 47]               KLM(!)      London_paris
# 2       10055.0            []    <Air France> (12)      Madrid_milan
# 3       10065.0  [24, 43, 87]  (British Airways. )  London_stockholm
# 4       10075.0          [13]       12. Air France    Budapest_paris
# 5       10085.0      [67, 32]          "Swiss Air"   Brussels_london

# %%
df_New = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

df_New
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
newdf =  pd.DataFrame(df_New.RecentDelays, index = [0,1,2,3,4])
newdf
# Out:
#    RecentDelays
# 0      [23, 47]
# 1            []
# 2  [24, 43, 87]
# 3          [13]
# 4      [67, 32]

# %%
newdf.set_index(np_arange, inplace =True)
newdf
# Out:
#    RecentDelays
# 1      [23, 47]
# 2            []
# 3  [24, 43, 87]
# 4          [13]
# 5      [67, 32]

# %%
delays = pd.DataFrame(newdf['RecentDelays'].values.tolist(), columns=['delay_1','delay_2','delay_3'])
delays
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df.drop("RecentDelays", axis= 1 , inplace =True)
df
# Out:
#    FlightNumber              Airline           From_To
# 1       10045.0               KLM(!)      London_paris
# 2       10055.0    <Air France> (12)      Madrid_milan
# 3       10065.0  (British Airways. )  London_stockholm
# 4       10075.0       12. Air France    Budapest_paris
# 5       10085.0          "Swiss Air"   Brussels_london

# %%
df = pd.concat([df, delays], axis = 1 )
df
# Out:
#    FlightNumber              Airline           From_To  delay_1  delay_2  \
# 0           NaN                  NaN               NaN     23.0     47.0
# 1       10045.0               KLM(!)      London_paris      NaN      NaN
# 2       10055.0    <Air France> (12)      Madrid_milan     24.0     43.0
# 3       10065.0  (British Airways. )  London_stockholm     13.0      NaN
# 4       10075.0       12. Air France    Budapest_paris     67.0     32.0
# 5       10085.0          "Swiss Air"   Brussels_london      NaN      NaN
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN
# 5      NaN
